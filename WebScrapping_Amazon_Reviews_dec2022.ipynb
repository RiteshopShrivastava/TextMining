# %% [markdown]
# <a href="https://colab.research.google.com/github/RiteshopShrivastava/TextMining/blob/main/WebScrapping_Amazon_Reviews_dec2022.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Amazon Reviews - Apple iPhone 7 (32GB) - Black**

# %%
# !pip install bs4
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !pip install requests
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from bs4 import BeautifulSoup
import requests

# %%
headerAgent = {'User-Agent': 'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/41.0.2228.0 Safari/537.36'}

#url='https://www.amazon.in/Apple-iPhone-Black-32GB-Storage/product-reviews/B01LZKSVRB/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews'

#url ='https://www.amazon.in/Apple-iPhone-Black-32GB-Storage/product-reviews/B01LZKSVRB/ref=cm_cr_arp_d_paging_btm_next_2?ie=UTF8&reviewerType=all_reviews&pageNumber=2'
#url = 'https://www.amazon.in/Apple-iPhone-Black-32GB-Storage/product-reviews/B01LZKSVRB/ref=cm_cr_getr_d_paging_btm_next_3?ie=UTF8&reviewerType=all_reviews&pageNumber=3'
#url = 'https://www.amazon.in/Apple-iPhone-Black-32GB-Storage/product-reviews/B01LZKSVRB/ref=cm_cr_getr_d_paging_btm_next_4?ie=UTF8&reviewerType=all_reviews&pageNumber=4'
url = 'https://www.amazon.in/Apple-iPhone-Black-32GB-Storage/product-reviews/B01LZKSVRB/ref=cm_cr_getr_d_paging_btm_next_5?ie=UTF8&reviewerType=all_reviews&pageNumber=5'

# %%
page = requests.get(url,headers=headerAgent)

# %%
page
# Out:
# <Response [200]>

# %%
url
# Out:
# 'https://www.amazon.in/Apple-iPhone-Black-32GB-Storage/product-reviews/B01LZKSVRB/ref=cm_cr_getr_d_paging_btm_next_5?ie=UTF8&reviewerType=all_reviews&pageNumber=5'

# %%
page.content
# Out:
# b'<!doctype html><html lang="en-in" class="a-no-js" data-19ax5a9jf="dingo"><!-- sp:feature:head-start -->\n<head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/>\n<!-- sp:end-feature:head-start -->\n<!-- sp:feature:csm:head-open-part1 -->\n\n<script type=\'text/javascript\'>var ue_t0=ue_t0||+new Date();</script>\n<!-- sp:end-feature:csm:head-open-part1 -->\n<!-- sp:feature:cs-optimization -->\n<meta http-equiv=\'x-dns-prefetch-control\' content=\'on\'>\n<link rel="dns-prefetch" href="https://images-eu.ssl-images-amazon.com">\n<link rel="dns-prefetch" href="https://m.media-amazon.com">\n<link rel="dns-prefetch" href="https://completion.amazon.com">\n<!-- sp:end-feature:cs-optimization -->\n<!-- sp:feature:csm:head-open-part2 -->\n<script type=\'text/javascript\'>\nwindow.ue_ihb = (window.ue_ihb || window.ueinit || 0) + 1;\nif (window.ue_ihb === 1) {\n\nvar ue_csm = window,\n    ue_hob = +new Date();\n(function(d){var e=d.ue=d.ue||{},f=Date.now||function
# ...

# %%
soup = BeautifulSoup(page.content, 'html.parser')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE doctype html>
# <html class="a-no-js" data-19ax5a9jf="dingo" lang="en-in">
#  <!-- sp:feature:head-start -->
#  <head>
#   <script>
#    var aPageStart = (new Date()).getTime();
#   </script>
#   <meta charset="utf-8"/>
#   <!-- sp:end-feature:head-start -->
#   <!-- sp:feature:csm:head-open-part1 -->
#   <script type="text/javascript">
#    var ue_t0=ue_t0||+new Date();
#   </script>
#   <!-- sp:end-feature:csm:head-open-part1 -->
#   <!-- sp:feature:cs-optimization -->
#   <meta content="on" http-equiv="x-dns-prefetch-control"/>
#   <link href="https://images-eu.ssl-images-amazon.com" rel="dns-prefetch"/>
#   <link href="https://m.media-amazon.com" rel="dns-prefetch"/>
#   <link href="https://completion.amazon.com" rel="dns-prefetch"/>
#   <!-- sp:end-feature:cs-optimization -->
#   <!-- sp:feature:csm:head-open-part2 -->
#   <script type="text/javascript">
#    window.ue_ihb = (window.ue_ihb || window.ueinit || 0) + 1;
# if (window.ue_ihb === 1) {
#
# ...

# %%
soup
# Out:
# <!DOCTYPE doctype html>
# <html class="a-no-js" data-19ax5a9jf="dingo" lang="en-in"><!-- sp:feature:head-start -->
# <head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/>
# <!-- sp:end-feature:head-start -->
# <!-- sp:feature:csm:head-open-part1 -->
# <script type="text/javascript">var ue_t0=ue_t0||+new Date();</script>
# <!-- sp:end-feature:csm:head-open-part1 -->
# <!-- sp:feature:cs-optimization -->
# <meta content="on" http-equiv="x-dns-prefetch-control"/>
# <link href="https://images-eu.ssl-images-amazon.com" rel="dns-prefetch"/>
# <link href="https://m.media-amazon.com" rel="dns-prefetch"/>
# <link href="https://completion.amazon.com" rel="dns-prefetch"/>
# <!-- sp:end-feature:cs-optimization -->
# <!-- sp:feature:csm:head-open-part2 -->
# <script type="text/javascript">
# window.ue_ihb = (window.ue_ihb || window.ueinit || 0) + 1;
# if (window.ue_ihb === 1) {
#
# var ue_csm = window,
#     ue_hob = +new Date();
# ...

# %% [markdown]
# **Extracting name of reviewer**

# %%
name = soup.find_all('span', class_='a-profile-name')

# %%
name
# Out:
# [<span class="a-profile-name">Navneet Nishant</span>,
#  <span class="a-profile-name">Kamesh</span>,
#  <span class="a-profile-name">JILLIAN SAWERS</span>,
#  <span class="a-profile-name">pravinkumar D Kurade</span>,
#  <span class="a-profile-name">Vineeth Kuttappan Nair</span>,
#  <span class="a-profile-name">Amazon Customer</span>,
#  <span class="a-profile-name">sneha</span>,
#  <span class="a-profile-name">Arun A</span>,
#  <span class="a-profile-name">Pabdurrahmanraha</span>,
#  <span class="a-profile-name">Utpal Das</span>,
#  <span class="a-profile-name">Daanesh</span>,
#  <span class="a-profile-name">iD</span>]

# %%
cust_name=[]
for i in range (0,len(name)):
    cust_name.append(name[i].get_text())

# %%
cust_name
# Out:
# ['Navneet Nishant',
#  'Kamesh',
#  'JILLIAN SAWERS',
#  'pravinkumar D Kurade',
#  'Vineeth Kuttappan Nair',
#  'Amazon Customer',
#  'sneha',
#  'Arun A',
#  'Pabdurrahmanraha',
#  'Utpal Das',
#  'Daanesh',
#  'iD']

# %%
#Removing duplicate records from top
cust_name.pop(0)
# Out:
# 'Navneet Nishant'

# %%
#Removing duplicate records from top
cust_name.pop(0)
# Out:
# 'Kamesh'

# %%
cust_name
# Out:
# ['JILLIAN SAWERS',
#  'pravinkumar D Kurade',
#  'Vineeth Kuttappan Nair',
#  'Amazon Customer',
#  'sneha',
#  'Arun A',
#  'Pabdurrahmanraha',
#  'Utpal Das',
#  'Daanesh',
#  'iD']

# %% [markdown]
# **Extracting Title of review**

# %%
title = soup.find_all('a',class_='review-title-content')

# %%
title
# Out:
# [<a class="a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold" data-hook="review-title" href="/gp/customer-reviews/R2B30MDR1WFZIS/ref=cm_cr_arp_d_rvw_ttl?ie=UTF8&amp;ASIN=B01LZKSVRB">
#  <span>GOOD FAST DELIVERY AND. NICE PRODUCT</span>
#  </a>,
#  <a class="a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold" data-hook="review-title" href="/gp/customer-reviews/R3FS7RYX7QXGJ0/ref=cm_cr_arp_d_rvw_ttl?ie=UTF8&amp;ASIN=B01LZKSVRB">
#  <span>Small lovely Mobile</span>
#  </a>,
#  <a class="a-size-base a-link-normal review-title a-color-base review-title-content a-text-bold" data-hook="review-title" href="/gp/customer-reviews/R21QLV46Z0CWBC/ref=cm_cr_arp_d_rvw_ttl?ie=UTF8&amp;ASIN=B01LZKSVRB">
#  <span>Excellent</span>
#  </a>,
# ...

# %%
review_title=[]
for i in range (0,len(title)):
    review_title.append(title[i].get_text())

# %%
review_title
# Out:
# ['\nGOOD FAST DELIVERY AND. NICE PRODUCT\n',
#  '\nSmall lovely Mobile\n',
#  '\nExcellent\n',
#  '\nPoor battery,\n',
#  '\nAffordable ❤️💯\n',
#  '\nNew I phone 7 battery health showing 96%!!!!\n',
#  '\nBattery problem\n',
#  '\nNow I know why people use an iPhone, especially the 7, much improved than 6s, best VFM phone\n',
#  '\nVery nice\n',
#  '\nGo for it...\n']

# %%
review_title[:] = [x.lstrip('\n') for x in review_title]

# %%
review_title
# Out:
# ['GOOD FAST DELIVERY AND. NICE PRODUCT\n',
#  'Small lovely Mobile\n',
#  'Excellent\n',
#  'Poor battery,\n',
#  'Affordable ❤️💯\n',
#  'New I phone 7 battery health showing 96%!!!!\n',
#  'Battery problem\n',
#  'Now I know why people use an iPhone, especially the 7, much improved than 6s, best VFM phone\n',
#  'Very nice\n',
#  'Go for it...\n']

# %%
review_title[:] = [x.rstrip('\n') for x in review_title]

# %%
review_title
# Out:
# ['GOOD FAST DELIVERY AND. NICE PRODUCT',
#  'Small lovely Mobile',
#  'Excellent',
#  'Poor battery,',
#  'Affordable ❤️💯',
#  'New I phone 7 battery health showing 96%!!!!',
#  'Battery problem',
#  'Now I know why people use an iPhone, especially the 7, much improved than 6s, best VFM phone',
#  'Very nice',
#  'Go for it...']

# %% [markdown]
# **Extracting star rating**

# %%
rating = soup.find_all('i', class_ ='review-rating')

# %%
rating
# Out:
# [<i class="a-icon a-icon-star a-star-5 review-rating" data-hook="review-star-rating-view-point"><span class="a-icon-alt">5.0 out of 5 stars</span></i>,
#  <i class="a-icon a-icon-star a-star-3 review-rating" data-hook="review-star-rating-view-point"><span class="a-icon-alt">3.0 out of 5 stars</span></i>,
#  <i class="a-icon a-icon-star a-star-4 review-rating" data-hook="review-star-rating"><span class="a-icon-alt">4.0 out of 5 stars</span></i>,
#  <i class="a-icon a-icon-star a-star-4 review-rating" data-hook="review-star-rating"><span class="a-icon-alt">4.0 out of 5 stars</span></i>,
#  <i class="a-icon a-icon-star a-star-5 review-rating" data-hook="review-star-rating"><span class="a-icon-alt">5.0 out of 5 stars</span></i>,
#  <i class="a-icon a-icon-star a-star-1 review-rating" data-hook="review-star-rating"><span class="a-icon-alt">1.0 out of 5 stars</span></i>,
# ...

# %%
rate =[]
for i in range (0,len(rating)):
    rate.append(rating[i].get_text())

# %%
rate
# Out:
# ['5.0 out of 5 stars',
#  '3.0 out of 5 stars',
#  '4.0 out of 5 stars',
#  '4.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '4.0 out of 5 stars',
#  '4.0 out of 5 stars',
#  '4.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '4.0 out of 5 stars',
#  '4.0 out of 5 stars']

# %%
rate.pop(0)
# Out:
# '5.0 out of 5 stars'

# %%
rate.pop(0)
# Out:
# '3.0 out of 5 stars'

# %%
rate
# Out:
# ['4.0 out of 5 stars',
#  '4.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '1.0 out of 5 stars',
#  '4.0 out of 5 stars',
#  '4.0 out of 5 stars',
#  '4.0 out of 5 stars',
#  '5.0 out of 5 stars',
#  '4.0 out of 5 stars',
#  '4.0 out of 5 stars']

# %% [markdown]
# **Extracting review**

# %%
review= soup.find_all('span', class_='review-text')

# %%
review
# Out:
# [<span class="a-size-base review-text review-text-content" data-hook="review-body">
#  <span>Seems to overheat quite quickly and also my old samsung 5 picked up the phone signal so much better.  I used to be able to tether the wifi to my phone from home and now i can't.  Which is a real disappointment.  I mainly brought it because i have ipad and airmac and wanted to be able to airdrop but the important thing, that it picks up signal from phone is actually pretty poor.</span>
#  </span>,
#  <span class="a-size-base review-text review-text-content" data-hook="review-body">
#  <span>I love small mobile that’s Why I went for this but other than that space problem I don’t have any issue with this I like it I really love it I will definitely recommend you if you don’t want more applications just go for it if you have more budget then take 60 4GB at least</span>
#  </span>,
#  <span class="a-size-base review-text review-text-content" data-hook="review-body">
# ...

# %%
review_content =[]
for i in range(0,len(review)):
    review_content.append(review[i].get_text())
review_content
# Out:
# ["\nSeems to overheat quite quickly and also my old samsung 5 picked up the phone signal so much better.  I used to be able to tether the wifi to my phone from home and now i can't.  Which is a real disappointment.  I mainly brought it because i have ipad and airmac and wanted to be able to airdrop but the important thing, that it picks up signal from phone is actually pretty poor.\n",
#  '\nI love small mobile that’s Why I went for this but other than that space problem I don’t have any issue with this I like it I really love it I will definitely recommend you if you don’t want more applications just go for it if you have more budget then take 60 4GB at least\n',
# ...

# %%
review_content[:]= [x.lstrip('\n\n') for x in review_content]

# %%
review_content[:]= [x.rstrip('\n\n') for x in review_content]

# %%
review_content
# Out:
# ["Seems to overheat quite quickly and also my old samsung 5 picked up the phone signal so much better.  I used to be able to tether the wifi to my phone from home and now i can't.  Which is a real disappointment.  I mainly brought it because i have ipad and airmac and wanted to be able to airdrop but the important thing, that it picks up signal from phone is actually pretty poor.",
#  'I love small mobile that’s Why I went for this but other than that space problem I don’t have any issue with this I like it I really love it I will definitely recommend you if you don’t want more applications just go for it if you have more budget then take 60 4GB at least',
# ...

# %%
# Variables in which data is saved 
cust_name
review_title
rate
review_content
# Out:
# ["Seems to overheat quite quickly and also my old samsung 5 picked up the phone signal so much better.  I used to be able to tether the wifi to my phone from home and now i can't.  Which is a real disappointment.  I mainly brought it because i have ipad and airmac and wanted to be able to airdrop but the important thing, that it picks up signal from phone is actually pretty poor.",
#  'I love small mobile that’s Why I went for this but other than that space problem I don’t have any issue with this I like it I really love it I will definitely recommend you if you don’t want more applications just go for it if you have more budget then take 60 4GB at least',
# ...

# %% [markdown]
# **Saving all the review data in a dataframe**

# %%
import pandas as pd
df_scrapping = pd.DataFrame()
df_scrapping
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df_scrapping['Customer_name']= cust_name
df_scrapping['Title']= review_title
df_scrapping['Rating'] = rate
df_scrapping['Review']= review_content
df_scrapping
# Out:
#             Customer_name                                              Title  \
# 0          JILLIAN SAWERS               GOOD FAST DELIVERY AND. NICE PRODUCT
# 1    pravinkumar D Kurade                                Small lovely Mobile
# 2  Vineeth Kuttappan Nair                                          Excellent
# 3         Amazon Customer                                      Poor battery,
# 4                   sneha                                     Affordable ❤️💯
# 5                  Arun A       New I phone 7 battery health showing 96%!!!!
# 6        Pabdurrahmanraha                                    Battery problem
# 7               Utpal Das  Now I know why people use an iPhone, especiall...
# 8                 Daanesh                                          Very nice
# 9                      iD                                       Go for it...
#
#                Rating                                             Review
# ...

# %% [markdown]
# **Downloading the file in a csv format**

# %%
df_scrapping.to_csv(r'D:\Data Science\Amazon_reviews5.csv', index=True)

# %%
df_scrapping.to_csv(r'Amazon_reviews5.csv', index=True)
